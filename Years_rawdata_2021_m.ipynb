# %% [markdown]
# <a href="https://colab.research.google.com/github/shovagelal/Open-source-Practice/blob/main/Years_rawdata_2021_m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 1: Load Data
file_path = '/content/drive/MyDrive/bob_publication_data/years/2021/raw/2021_m/0.csv'  # Replace with the actual path to your CSV file
df = pd.read_csv(file_path)

# %%
# Step 2: Remove Unnecessary Columns
columns_to_remove = ["X", "uni_time", "numeric.time"]
df_cleaned = df.drop(columns=columns_to_remove, errors='ignore')

# %%
# Step 3: Summarize the Data
print("Summary of the data:")
print(df_cleaned.describe(include='all'))
# Out:
# Summary of the data:
#            Unnamed: 0                 time          t_i_1          t_i_2  \
# count   525599.000000               525599  286537.000000  286682.000000
# unique            NaN               525539            NaN            NaN
# top               NaN  2021-03-28 01:04:00            NaN            NaN
# freq              NaN                    2            NaN            NaN
# mean    262800.000000                  NaN      11.952397      11.858421
# std     151727.506405                  NaN       5.984411       5.654970
# min          1.000000                  NaN      -3.380000      -3.250000
# 25%     131400.500000                  NaN       6.690000       7.000000
# 50%     262800.000000                  NaN      12.380000      12.060000
# 75%     394199.500000                  NaN      16.250000      15.910000
# max     525599.000000                  NaN      33.560000      32.880000
#
#                 t_i_3          t_i_4          t_i_5            t_o  \
# ...

# %%
# Step 4: Visualize the Data

# Convert 'time' column to datetime for better plotting
df_cleaned['time'] = pd.to_datetime(df_cleaned['time'])

# %%
# Plotting temperature inside the hive
plt.figure(figsize=(10, 6))
plt.plot(df_cleaned['time'], df_cleaned['t_i_1'], label='t_i_1')
plt.plot(df_cleaned['time'], df_cleaned['t_i_2'], label='t_i_2')
plt.plot(df_cleaned['time'], df_cleaned['t_i_3'], label='t_i_3')
plt.plot(df_cleaned['time'], df_cleaned['t_i_4'], label='t_i_4')
plt.plot(df_cleaned['time'], df_cleaned['t_i_5'], label='t_i_5')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Inside the Hive Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting outside temperature
plt.figure(figsize=(10, 6))
plt.plot(df_cleaned['time'], df_cleaned['t_o'], label='t_o', color='orange')
plt.xlabel('Time')
plt.ylabel('Outside Temperature (°C)')
plt.title('Outside Temperature Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting hive weight
plt.figure(figsize=(10, 6))
plt.plot(df_cleaned['time'], df_cleaned['weight_kg'], label='Weight (kg)', color='green')
plt.xlabel('Time')
plt.ylabel('Weight (kg)')
plt.title('Hive Weight Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting humidity
plt.figure(figsize=(10, 6))
plt.plot(df_cleaned['time'], df_cleaned['h'], label='Relative Humidity (%)', color='blue')
plt.xlabel('Time')
plt.ylabel('Relative Humidity (%)')
plt.title('Relative Humidity Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting pressure
plt.figure(figsize=(10, 6))
plt.plot(df_cleaned['time'], df_cleaned['p'], label='Pressure (hPa)', color='purple')
plt.xlabel('Time')
plt.ylabel('Pressure (hPa)')
plt.title('Pressure Over Time')
plt.legend()
plt.grid(True)
plt.show()
